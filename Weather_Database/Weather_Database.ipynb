# %%
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime

from config import weather_api_key
from config import g_key

# %%
# Generate 2,000 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# Get the nearest city using the citipy module.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
len(cities)
# Out:
# 752

# %%
# Perform an API call with the OpenWeatherMap.

# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")
# use enumerate() method to loop index and item simutanously 
for i, item in enumerate(cities):
    if i % 50 == 0 and i != 0 :
        record_count = 1  
        set_count +=1 
    # build URL for API call
    url = basic_url + '&q=' + item
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {item}')
    # increment record count
    record_count +=1

    try:
        js = requests.get(url).json()
        city_name = item
        city_country = js['sys']['country']
        city_UTCdate = js['dt']
        city_date = datetime.utcfromtimestamp(city_UTCdate).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = js['coord']['lat']
        city_lon = js['coord']['lon']
        city_max_temp = js['main']['temp_max']
        city_humidity = js['main']['humidity']
        city_clouds = js['clouds']['all']
        city_wind = js['wind']['speed']
        city_weather_description = js['weather'][0]['description']


        # append as a list of dictionaries
        city_data.append({'City':city_name, 'Country':city_country, 'Date':city_date, 
                        'Lat':city_lat, 'Lng': city_lon,'Max Temp':city_max_temp,
                        'Humidity':city_humidity,'Cloudiness': city_clouds,'Wind Speed':city_wind,
                        'Current Description':city_weather_description,})
    except:
        print("City not found. Skipping...")
        pass
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | torbay
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | pevek
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | ronne
# Processing Record 10 of Set 1 | gafanha da encarnacao
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | fortuna
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | sorland
# Processing Record 15 of Set 1 | mahebourg
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | namibe
# Processing Record 18 of Set 1 | charters towers
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | norman wells
# Processing Record 21 of Set 1 | nago
# Processing Record 22 of Set 1 | iaciara
# Processing Record 23 of Set 1 | bethel
# Processing Record 24 of Set 1 | san patricio
# Processing Record 25 of Set 1 | qaanaaq
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | vieux fort
# Processing Record 28 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | cape town
# Processing Record 31 of Set 1 | izhma
# Processing Record 32 of Set 1 | kurilsk
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | kamenka
# Processing Record 35 of Set 1 | bad sooden-allendorf
# Processing Record 36 of Set 1 | naze
# Processing Record 37 of Set 1 | aswan
# Processing Record 38 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | hambantota
# Processing Record 41 of Set 1 | katsuura
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | chokwe
# Processing Record 44 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | vardo
# Processing Record 47 of Set 1 | ufimskiy
# Processing Record 48 of Set 1 | carnarvon
# Processing Record 49 of Set 1 | tiksi
# Processing Record 50 of Set 1 | kropotkin
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 2 | sortland
# Processing Record 4 of Set 2 | yarmolyntsi
# Processing Record 5 of Set 2 | ous
# Processing Record 6 of Set 2 | airai
# Processing Record 7 of Set 2 | madimba
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | clyde river
# Processing Record 10 of Set 2 | rosetta
# Processing Record 11 of Set 2 | praia
# Processing Record 12 of Set 2 | smila
# Processing Record 13 of Set 2 | tuktoyaktuk
# Processing Record 14 of Set 2 | wamba
# Processing Record 15 of Set 2 | padang
# Processing Record 16 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 2 | sayyan
# Processing Record 18 of Set 2 | jamestown
# Processing Record 19 of Set 2 | punta arenas
# Processing Record 20 of Set 2 | arraial do cabo
# Processing Record 21 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 2 | kavieng
# Processing Record 23 of Set 2 | bubaque
# Processing Record 24 of Set 2 | faanui
# Processing Record 25 of Set 2 | guerrero negro
# Processing Record 26 of Set 2 | santiago de chuco
# Processing Record 27 of Set 2 | pribelskiy
# City not found. Skipping...
# Processing Record 28 of Set 2 | ankara
# Processing Record 29 of Set 2 | vanimo
# Processing Record 30 of Set 2 | vestmanna
# Processing Record 31 of Set 2 | riohacha
# Processing Record 32 of Set 2 | isangel
# Processing Record 33 of Set 2 | yulara
# Processing Record 34 of Set 2 | moose factory
# Processing Record 35 of Set 2 | saskylakh
# Processing Record 36 of Set 2 | new norfolk
# Processing Record 37 of Set 2 | juneau
# Processing Record 38 of Set 2 | bengkulu
# Processing Record 39 of Set 2 | castro
# Processing Record 40 of Set 2 | hamilton
# Processing Record 41 of Set 2 | nikolskoye
# Processing Record 42 of Set 2 | saint-joseph
# Processing Record 43 of Set 2 | tessalit
# Processing Record 44 of Set 2 | vao
# Processing Record 45 of Set 2 | honningsvag
# Processing Record 46 of Set 2 | atuona
# Processing Record 47 of Set 2 | port alfred
# Processing Record 48 of Set 2 | surovatikha
# Processing Record 49 of Set 2 | yellowknife
# Processing Record 50 of Set 2 | manokwari
# Processing Record 1 of Set 3 | port hardy
# Processing Record 2 of Set 3 | komsomolskiy
# Processing Record 3 of Set 3 | yeppoon
# Processing Record 4 of Set 3 | buraydah
# Processing Record 5 of Set 3 | tasiilaq
# Processing Record 6 of Set 3 | hilo
# Processing Record 7 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 3 | stranda
# Processing Record 9 of Set 3 | camacha
# Processing Record 10 of Set 3 | kodiak
# Processing Record 11 of Set 3 | nyurba
# Processing Record 12 of Set 3 | avarua
# Processing Record 13 of Set 3 | billings
# Processing Record 14 of Set 3 | tual
# Processing Record 15 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 3 | axim
# Processing Record 17 of Set 3 | gornopravdinsk
# Processing Record 18 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 3 | mercedes
# Processing Record 20 of Set 3 | galveston
# Processing Record 21 of Set 3 | kapaa
# Processing Record 22 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 3 | sangar
# Processing Record 24 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 25 of Set 3 | severo-kurilsk
# Processing Record 26 of Set 3 | umm lajj
# Processing Record 27 of Set 3 | salinopolis
# Processing Record 28 of Set 3 | lompoc
# Processing Record 29 of Set 3 | capitao poco
# Processing Record 30 of Set 3 | novo aripuana
# Processing Record 31 of Set 3 | rocha
# Processing Record 32 of Set 3 | arlit
# Processing Record 33 of Set 3 | filingue
# Processing Record 34 of Set 3 | bangui
# Processing Record 35 of Set 3 | bayan
# Processing Record 36 of Set 3 | saint-leu
# Processing Record 37 of Set 3 | talnakh
# Processing Record 38 of Set 3 | mount gambier
# Processing Record 39 of Set 3 | khatanga
# Processing Record 40 of Set 3 | jujuy
# City not found. Skipping...
# Processing Record 41 of Set 3 | verkhnevilyuysk
# Processing Record 42 of Set 3 | abnub
# Processing Record 43 of Set 3 | cherskiy
# Processing Record 44 of Set 3 | robertsport
# Processing Record 45 of Set 3 | mvomero
# Processing Record 46 of Set 3 | turkan
# Processing Record 47 of Set 3 | atlantic city
# Processing Record 48 of Set 3 | cidreira
# Processing Record 49 of Set 3 | yarensk
# Processing Record 50 of Set 3 | alofi
# Processing Record 1 of Set 4 | puerto narino
# Processing Record 2 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 4 | narsaq
# Processing Record 4 of Set 4 | verkhoyansk
# Processing Record 5 of Set 4 | aksu
# Processing Record 6 of Set 4 | saint george
# Processing Record 7 of Set 4 | palasa
# Processing Record 8 of Set 4 | tabas
# Processing Record 9 of Set 4 | pisco
# Processing Record 10 of Set 4 | buala
# Processing Record 11 of Set 4 | kahului
# Processing Record 12 of Set 4 | kimbe
# Processing Record 13 of Set 4 | marsassoum
# Processing Record 14 of Set 4 | batagay-alyta
# Processing Record 15 of Set 4 | arequipa
# Processing Record 16 of Set 4 | saint-pierre
# Processing Record 17 of Set 4 | port macquarie
# Processing Record 18 of Set 4 | foam lake
# Processing Record 19 of Set 4 | souillac
# Processing Record 20 of Set 4 | apartado
# Processing Record 21 of Set 4 | maine-soroa
# Processing Record 22 of Set 4 | bambous virieux
# Processing Record 23 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 4 | scarborough
# Processing Record 25 of Set 4 | vila velha
# Processing Record 26 of Set 4 | blackwater
# Processing Record 27 of Set 4 | ponta do sol
# Processing Record 28 of Set 4 | portland
# Processing Record 29 of Set 4 | aykhal
# Processing Record 30 of Set 4 | tecoanapa
# Processing Record 31 of Set 4 | port augusta
# Processing Record 32 of Set 4 | kruisfontein
# Processing Record 33 of Set 4 | coquimbo
# Processing Record 34 of Set 4 | khandbari
# Processing Record 35 of Set 4 | san cristobal
# Processing Record 36 of Set 4 | patacamaya
# Processing Record 37 of Set 4 | nanortalik
# Processing Record 38 of Set 4 | dhankuta
# Processing Record 39 of Set 4 | chase
# Processing Record 40 of Set 4 | geraldton
# Processing Record 41 of Set 4 | vetlanda
# Processing Record 42 of Set 4 | chuy
# Processing Record 43 of Set 4 | vostok
# Processing Record 44 of Set 4 | salalah
# Processing Record 45 of Set 4 | windsor
# Processing Record 46 of Set 4 | bodden town
# Processing Record 47 of Set 4 | lata
# Processing Record 48 of Set 4 | arman
# Processing Record 49 of Set 4 | thompson
# Processing Record 50 of Set 4 | dikson
# Processing Record 1 of Set 5 | lerwick
# Processing Record 2 of Set 5 | belaya gora
# Processing Record 3 of Set 5 | rabaul
# Processing Record 4 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 5 | penzance
# Processing Record 6 of Set 5 | san vicente
# Processing Record 7 of Set 5 | pinawa
# Processing Record 8 of Set 5 | wewak
# Processing Record 9 of Set 5 | kirakira
# Processing Record 10 of Set 5 | tombouctou
# Processing Record 11 of Set 5 | saldanha
# Processing Record 12 of Set 5 | chokurdakh
# Processing Record 13 of Set 5 | qandala
# Processing Record 14 of Set 5 | sakaiminato
# Processing Record 15 of Set 5 | edenderry
# Processing Record 16 of Set 5 | sinnamary
# Processing Record 17 of Set 5 | taoudenni
# Processing Record 18 of Set 5 | kaitangata
# Processing Record 19 of Set 5 | upernavik
# Processing Record 20 of Set 5 | ardistan
# City not found. Skipping...
# Processing Record 21 of Set 5 | ayagoz
# Processing Record 22 of Set 5 | parkersburg
# Processing Record 23 of Set 5 | kudahuvadhoo
# Processing Record 24 of Set 5 | taksimo
# Processing Record 25 of Set 5 | iskateley
# Processing Record 26 of Set 5 | port elizabeth
# Processing Record 27 of Set 5 | bull savanna
# Processing Record 28 of Set 5 | nome
# Processing Record 29 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 5 | svrljig
# Processing Record 31 of Set 5 | caravelas
# Processing Record 32 of Set 5 | ancud
# Processing Record 33 of Set 5 | ormara
# Processing Record 34 of Set 5 | waingapu
# Processing Record 35 of Set 5 | mayo
# Processing Record 36 of Set 5 | sibolga
# Processing Record 37 of Set 5 | provideniya
# Processing Record 38 of Set 5 | verkhnetulomskiy
# Processing Record 39 of Set 5 | lebu
# Processing Record 40 of Set 5 | ambon
# Processing Record 41 of Set 5 | udachnyy
# Processing Record 42 of Set 5 | san angelo
# Processing Record 43 of Set 5 | tapiramuta
# Processing Record 44 of Set 5 | road town
# Processing Record 45 of Set 5 | sri aman
# Processing Record 46 of Set 5 | te anau
# Processing Record 47 of Set 5 | atambua
# Processing Record 48 of Set 5 | ahipara
# Processing Record 49 of Set 5 | herat
# Processing Record 50 of Set 5 | bathsheba
# Processing Record 1 of Set 6 | bella union
# Processing Record 2 of Set 6 | iqaluit
# Processing Record 3 of Set 6 | husavik
# Processing Record 4 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 6 | jalu
# Processing Record 6 of Set 6 | kutum
# Processing Record 7 of Set 6 | dingle
# Processing Record 8 of Set 6 | tazovskiy
# Processing Record 9 of Set 6 | alpena
# Processing Record 10 of Set 6 | inta
# Processing Record 11 of Set 6 | jabinyanah
# Processing Record 12 of Set 6 | northeim
# Processing Record 13 of Set 6 | la brea
# Processing Record 14 of Set 6 | tautira
# Processing Record 15 of Set 6 | phan thiet
# Processing Record 16 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 17 of Set 6 | evansville
# Processing Record 18 of Set 6 | mina
# Processing Record 19 of Set 6 | kupang
# Processing Record 20 of Set 6 | aklavik
# Processing Record 21 of Set 6 | puerto leguizamo
# Processing Record 22 of Set 6 | indramayu
# Processing Record 23 of Set 6 | alice springs
# Processing Record 24 of Set 6 | muros
# Processing Record 25 of Set 6 | murchison
# Processing Record 26 of Set 6 | cabo san lucas
# Processing Record 27 of Set 6 | kieta
# Processing Record 28 of Set 6 | huntsville
# Processing Record 29 of Set 6 | yian
# City not found. Skipping...
# Processing Record 30 of Set 6 | dauphin
# Processing Record 31 of Set 6 | karratha
# Processing Record 32 of Set 6 | payson
# Processing Record 33 of Set 6 | entre rios
# Processing Record 34 of Set 6 | watrous
# Processing Record 35 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 36 of Set 6 | richards bay
# Processing Record 37 of Set 6 | waipawa
# Processing Record 38 of Set 6 | avera
# Processing Record 39 of Set 6 | tilichiki
# Processing Record 40 of Set 6 | deyang
# Processing Record 41 of Set 6 | hovd
# Processing Record 42 of Set 6 | dunedin
# Processing Record 43 of Set 6 | lagoa
# Processing Record 44 of Set 6 | ilulissat
# Processing Record 45 of Set 6 | luba
# Processing Record 46 of Set 6 | antofagasta
# Processing Record 47 of Set 6 | jumla
# Processing Record 48 of Set 6 | mata de sao joao
# Processing Record 49 of Set 6 | rio gallegos
# Processing Record 50 of Set 6 | sandwick
# Processing Record 1 of Set 7 | republic
# Processing Record 2 of Set 7 | severnyy
# Processing Record 3 of Set 7 | maceio
# Processing Record 4 of Set 7 | lovington
# Processing Record 5 of Set 7 | ostrovnoy
# Processing Record 6 of Set 7 | tuatapere
# Processing Record 7 of Set 7 | lazaro cardenas
# Processing Record 8 of Set 7 | opobo
# City not found. Skipping...
# Processing Record 9 of Set 7 | labuhan
# Processing Record 10 of Set 7 | la ronge
# Processing Record 11 of Set 7 | talmenka
# Processing Record 12 of Set 7 | vezirkopru
# Processing Record 13 of Set 7 | stokmarknes
# Processing Record 14 of Set 7 | aginskoye
# Processing Record 15 of Set 7 | wajid
# Processing Record 16 of Set 7 | boundiali
# Processing Record 17 of Set 7 | saint-philippe
# Processing Record 18 of Set 7 | mangan
# Processing Record 19 of Set 7 | leh
# Processing Record 20 of Set 7 | finschhafen
# Processing Record 21 of Set 7 | suntar
# Processing Record 22 of Set 7 | grindavik
# Processing Record 23 of Set 7 | panaba
# Processing Record 24 of Set 7 | rockhampton
# Processing Record 25 of Set 7 | kemijarvi
# Processing Record 26 of Set 7 | east london
# Processing Record 27 of Set 7 | zvishavane
# Processing Record 28 of Set 7 | rawson
# Processing Record 29 of Set 7 | laguna
# Processing Record 30 of Set 7 | qaqortoq
# Processing Record 31 of Set 7 | pokhara
# Processing Record 32 of Set 7 | kirensk
# Processing Record 33 of Set 7 | lumberton
# Processing Record 34 of Set 7 | victoria
# Processing Record 35 of Set 7 | kinsale
# Processing Record 36 of Set 7 | weinan
# Processing Record 37 of Set 7 | carutapera
# Processing Record 38 of Set 7 | sao gabriel da cachoeira
# Processing Record 39 of Set 7 | yarmouth
# Processing Record 40 of Set 7 | zhizdra
# Processing Record 41 of Set 7 | leerdam
# Processing Record 42 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 43 of Set 7 | nemuro
# Processing Record 44 of Set 7 | havre-saint-pierre
# Processing Record 45 of Set 7 | hurghada
# Processing Record 46 of Set 7 | viloco
# Processing Record 47 of Set 7 | broken hill
# Processing Record 48 of Set 7 | vila franca do campo
# Processing Record 49 of Set 7 | karaton
# Processing Record 50 of Set 7 | sovetskaya
# Processing Record 1 of Set 8 | palafrugell
# Processing Record 2 of Set 8 | esperance
# Processing Record 3 of Set 8 | port lincoln
# Processing Record 4 of Set 8 | muttupet
# Processing Record 5 of Set 8 | mamallapuram
# Processing Record 6 of Set 8 | beringovskiy
# Processing Record 7 of Set 8 | klaksvik
# Processing Record 8 of Set 8 | kathu
# Processing Record 9 of Set 8 | tura
# Processing Record 10 of Set 8 | sembakung
# Processing Record 11 of Set 8 | fare
# Processing Record 12 of Set 8 | nalut
# Processing Record 13 of Set 8 | susanville
# Processing Record 14 of Set 8 | les cayes
# Processing Record 15 of Set 8 | moree
# Processing Record 16 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 17 of Set 8 | pavda
# City not found. Skipping...
# Processing Record 18 of Set 8 | biak
# Processing Record 19 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 20 of Set 8 | asfi
# Processing Record 21 of Set 8 | aneho
# Processing Record 22 of Set 8 | teya
# Processing Record 23 of Set 8 | poso
# Processing Record 24 of Set 8 | sao filipe
# Processing Record 25 of Set 8 | aracatuba
# Processing Record 26 of Set 8 | nisia floresta
# Processing Record 27 of Set 8 | vilhena
# Processing Record 28 of Set 8 | safaga
# Processing Record 29 of Set 8 | andra
# Processing Record 30 of Set 8 | vestmannaeyjar
# Processing Record 31 of Set 8 | hualmay
# Processing Record 32 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 33 of Set 8 | mount isa
# Processing Record 34 of Set 8 | armizonskoye
# Processing Record 35 of Set 8 | fairbanks
# Processing Record 36 of Set 8 | hofn
# Processing Record 37 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 38 of Set 8 | lensk
# Processing Record 39 of Set 8 | bocaranga
# City not found. Skipping...
# Processing Record 40 of Set 8 | saint anthony
# Processing Record 41 of Set 8 | nipawin
# Processing Record 42 of Set 8 | lokachi
# Processing Record 43 of Set 8 | broome
# Processing Record 44 of Set 8 | tiznit
# Processing Record 45 of Set 8 | brus
# Processing Record 46 of Set 8 | mandalgovi
# Processing Record 47 of Set 8 | namatanai
# Processing Record 48 of Set 8 | khapa
# Processing Record 49 of Set 8 | hasaki
# Processing Record 50 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 9 | ucluelet
# Processing Record 2 of Set 9 | riyadh
# Processing Record 3 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 4 of Set 9 | kisangani
# Processing Record 5 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 6 of Set 9 | aquiraz
# Processing Record 7 of Set 9 | kabo
# Processing Record 8 of Set 9 | pedasi
# Processing Record 9 of Set 9 | kununurra
# Processing Record 10 of Set 9 | wilmington
# Processing Record 11 of Set 9 | artyom
# Processing Record 12 of Set 9 | comodoro rivadavia
# Processing Record 13 of Set 9 | payo
# Processing Record 14 of Set 9 | iralaya
# Processing Record 15 of Set 9 | peleduy
# Processing Record 16 of Set 9 | soyo
# Processing Record 17 of Set 9 | chateauroux
# Processing Record 18 of Set 9 | peruibe
# Processing Record 19 of Set 9 | beloha
# Processing Record 20 of Set 9 | slobozia
# Processing Record 21 of Set 9 | malinyi
# Processing Record 22 of Set 9 | camacupa
# Processing Record 23 of Set 9 | chake chake
# Processing Record 24 of Set 9 | uray
# Processing Record 25 of Set 9 | hauterive
# Processing Record 26 of Set 9 | pangnirtung
# Processing Record 27 of Set 9 | nuuk
# Processing Record 28 of Set 9 | mataram
# Processing Record 29 of Set 9 | olafsvik
# Processing Record 30 of Set 9 | codrington
# Processing Record 31 of Set 9 | luderitz
# Processing Record 32 of Set 9 | ust-maya
# Processing Record 33 of Set 9 | tromso
# Processing Record 34 of Set 9 | mansa
# Processing Record 35 of Set 9 | elmadag
# Processing Record 36 of Set 9 | chapais
# Processing Record 37 of Set 9 | ayan
# Processing Record 38 of Set 9 | goma
# Processing Record 39 of Set 9 | westport
# Processing Record 40 of Set 9 | hobyo
# Processing Record 41 of Set 9 | ziro
# Processing Record 42 of Set 9 | karanja
# Processing Record 43 of Set 9 | rock hill
# Processing Record 44 of Set 9 | flin flon
# Processing Record 45 of Set 9 | chalus
# Processing Record 46 of Set 9 | opuwo
# Processing Record 47 of Set 9 | worland
# Processing Record 48 of Set 9 | meadow lake
# Processing Record 49 of Set 9 | lianran
# Processing Record 50 of Set 9 | samarai
# Processing Record 1 of Set 10 | sitka
# Processing Record 2 of Set 10 | svetlaya
# Processing Record 3 of Set 10 | nuevo progreso
# Processing Record 4 of Set 10 | taltal
# Processing Record 5 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 6 of Set 10 | griffith
# Processing Record 7 of Set 10 | farafangana
# Processing Record 8 of Set 10 | arvika
# Processing Record 9 of Set 10 | yantal
# Processing Record 10 of Set 10 | baker city
# Processing Record 11 of Set 10 | yunyang
# Processing Record 12 of Set 10 | dourados
# Processing Record 13 of Set 10 | pijijiapan
# Processing Record 14 of Set 10 | van
# Processing Record 15 of Set 10 | sobolevo
# Processing Record 16 of Set 10 | takoradi
# Processing Record 17 of Set 10 | shache
# Processing Record 18 of Set 10 | orgun
# City not found. Skipping...
# Processing Record 19 of Set 10 | tigre
# Processing Record 20 of Set 10 | acapulco
# Processing Record 21 of Set 10 | lamesa
# Processing Record 22 of Set 10 | dwarka
# Processing Record 23 of Set 10 | galesong
# Processing Record 24 of Set 10 | santa fe
# Processing Record 25 of Set 10 | potzu
# City not found. Skipping...
# Processing Record 26 of Set 10 | virginia beach
# Processing Record 27 of Set 10 | nha trang
# Processing Record 28 of Set 10 | makakilo city
# Processing Record 29 of Set 10 | bonthe
# Processing Record 30 of Set 10 | zyryanka
# Processing Record 31 of Set 10 | gillette
# Processing Record 32 of Set 10 | anchorage
# Processing Record 33 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 34 of Set 10 | dharmadam
# Processing Record 35 of Set 10 | whitehorse
# Processing Record 36 of Set 10 | parauna
# Processing Record 37 of Set 10 | puerto escondido
# Processing Record 38 of Set 10 | santa clara
# Processing Record 39 of Set 10 | grand-santi
# Processing Record 40 of Set 10 | mananjary
# Processing Record 41 of Set 10 | doha
# Processing Record 42 of Set 10 | japura
# Processing Record 43 of Set 10 | omachi
# Processing Record 44 of Set 10 | jega
# Processing Record 45 of Set 10 | ugoofaaru
# Processing Record 46 of Set 10 | lorengau
# Processing Record 47 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 10 | vilyuysk
# Processing Record 49 of Set 10 | san pedro
# Processing Record 50 of Set 10 | korop
# Processing Record 1 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 11 | ovsyanka
# Processing Record 3 of Set 11 | igarka
# Processing Record 4 of Set 11 | steinbach
# Processing Record 5 of Set 11 | cuamba
# Processing Record 6 of Set 11 | burnie
# Processing Record 7 of Set 11 | ishigaki
# Processing Record 8 of Set 11 | sola
# Processing Record 9 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 10 of Set 11 | yakeshi
# Processing Record 11 of Set 11 | sao joao da barra
# Processing Record 12 of Set 11 | jinka
# Processing Record 13 of Set 11 | kuva
# City not found. Skipping...
# Processing Record 14 of Set 11 | rio grande
# Processing Record 15 of Set 11 | metu
# Processing Record 16 of Set 11 | zhoucheng
# Processing Record 17 of Set 11 | austin
# Processing Record 18 of Set 11 | sandakan
# Processing Record 19 of Set 11 | vetluga
# Processing Record 20 of Set 11 | sistranda
# Processing Record 21 of Set 11 | bratsk
# Processing Record 22 of Set 11 | arcachon
# Processing Record 23 of Set 11 | gualeguay
# Processing Record 24 of Set 11 | lipin bor
# Processing Record 25 of Set 11 | werda
# Processing Record 26 of Set 11 | egvekinot
# Processing Record 27 of Set 11 | vanavara
# Processing Record 28 of Set 11 | erenhot
# Processing Record 29 of Set 11 | quang ngai
# Processing Record 30 of Set 11 | saint-georges
# Processing Record 31 of Set 11 | kharabali
# Processing Record 32 of Set 11 | methoni
# Processing Record 33 of Set 11 | san juan
# Processing Record 34 of Set 11 | dalbandin
# Processing Record 35 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 11 | ginir
# Processing Record 37 of Set 11 | longyearbyen
# Processing Record 38 of Set 11 | batemans bay
# Processing Record 39 of Set 11 | rudbar
# Processing Record 40 of Set 11 | kon tum
# Processing Record 41 of Set 11 | okha
# Processing Record 42 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 11 | cervia
# Processing Record 44 of Set 11 | channel-port aux basques
# Processing Record 45 of Set 11 | atbasar
# Processing Record 46 of Set 11 | ubinskoye
# Processing Record 47 of Set 11 | fort-shevchenko
# Processing Record 48 of Set 11 | laibin
# Processing Record 49 of Set 11 | mgachi
# Processing Record 50 of Set 11 | ayios andreas
# City not found. Skipping...
# Processing Record 1 of Set 12 | poum
# Processing Record 2 of Set 12 | ampanihy
# Processing Record 3 of Set 12 | montbrison
# Processing Record 4 of Set 12 | tome
# Processing Record 5 of Set 12 | mandiana
# Processing Record 6 of Set 12 | semenivka
# Processing Record 7 of Set 12 | leningradskiy
# Processing Record 8 of Set 12 | lincoln
# Processing Record 9 of Set 12 | ondjiva
# Processing Record 10 of Set 12 | hirson
# Processing Record 11 of Set 12 | solenzo
# Processing Record 12 of Set 12 | port moresby
# Processing Record 13 of Set 12 | mehamn
# Processing Record 14 of Set 12 | guayaramerin
# Processing Record 15 of Set 12 | nauta
# Processing Record 16 of Set 12 | simao
# Processing Record 17 of Set 12 | nizhneudinsk
# Processing Record 18 of Set 12 | muzhi
# Processing Record 19 of Set 12 | pafos
# Processing Record 20 of Set 12 | zhigansk
# Processing Record 21 of Set 12 | asau
# Processing Record 22 of Set 12 | ilebo
# Processing Record 23 of Set 12 | mezen
# Processing Record 24 of Set 12 | westlock
# Processing Record 25 of Set 12 | puerto carreno
# Processing Record 26 of Set 12 | santa marta
# Processing Record 27 of Set 12 | aranos
# Processing Record 28 of Set 12 | salina
# Processing Record 29 of Set 12 | litovko
# Processing Record 30 of Set 12 | flinders
# Processing Record 31 of Set 12 | guilin
# Processing Record 32 of Set 12 | barra do garcas
# Processing Record 33 of Set 12 | hay river
# Processing Record 34 of Set 12 | paris
# Processing Record 35 of Set 12 | yarada
# Processing Record 36 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 37 of Set 12 | kjollefjord
# Processing Record 38 of Set 12 | esna
# Processing Record 39 of Set 12 | taburi
# City not found. Skipping...
# Processing Record 40 of Set 12 | lavrentiya
# Processing Record 41 of Set 12 | abu samrah
# Processing Record 42 of Set 12 | abdulino
# Processing Record 43 of Set 12 | julana
# City not found. Skipping...
# Processing Record 44 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 45 of Set 12 | saint pete beach
# Processing Record 46 of Set 12 | bilma
# Processing Record 47 of Set 12 | kichera
# Processing Record 48 of Set 12 | ozinki
# Processing Record 49 of Set 12 | chimoio
# Processing Record 50 of Set 12 | marsa matruh
# Processing Record 1 of Set 13 | zhangye
# Processing Record 2 of Set 13 | touros
# Processing Record 3 of Set 13 | wagar
# Processing Record 4 of Set 13 | constitucion
# Processing Record 5 of Set 13 | korem
# Processing Record 6 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 13 | mogadishu
# Processing Record 8 of Set 13 | turayf
# Processing Record 9 of Set 13 | emba
# Processing Record 10 of Set 13 | mersin
# Processing Record 11 of Set 13 | ostersund
# Processing Record 12 of Set 13 | timizart
# Processing Record 13 of Set 13 | russkaya polyana
# Processing Record 14 of Set 13 | ofunato
# Processing Record 15 of Set 13 | saint-augustin
# Processing Record 16 of Set 13 | nurota
# Processing Record 17 of Set 13 | conceicao da barra
# Processing Record 18 of Set 13 | hvammstangi
# City not found. Skipping...
# Processing Record 19 of Set 13 | quatre cocos
# Processing Record 20 of Set 13 | saint-francois
# Processing Record 21 of Set 13 | meulaboh
# Processing Record 22 of Set 13 | fomboni
# Processing Record 23 of Set 13 | lima
# Processing Record 24 of Set 13 | imbituba
# Processing Record 25 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 13 | jagodina
# Processing Record 27 of Set 13 | gornyy
# Processing Record 28 of Set 13 | coihaique
# Processing Record 29 of Set 13 | andenes
# Processing Record 30 of Set 13 | winton
# Processing Record 31 of Set 13 | pasni
# Processing Record 32 of Set 13 | berlevag
# Processing Record 33 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 34 of Set 13 | kenai
# Processing Record 35 of Set 13 | linguere
# Processing Record 36 of Set 13 | omboue
# Processing Record 37 of Set 13 | katiola
# Processing Record 38 of Set 13 | fecamp
# Processing Record 39 of Set 13 | mirnyy
# Processing Record 40 of Set 13 | yumen
# Processing Record 41 of Set 13 | pochutla
# Processing Record 42 of Set 13 | aragats
# Processing Record 43 of Set 13 | iquique
# Processing Record 44 of Set 13 | qui nhon
# Processing Record 45 of Set 13 | hirado
# Processing Record 46 of Set 13 | san lawrenz
# Processing Record 47 of Set 13 | kurchum
# Processing Record 48 of Set 13 | radhanpur
# Processing Record 49 of Set 13 | mahanoro
# Processing Record 50 of Set 13 | srednekolymsk
# Processing Record 1 of Set 14 | voznesenye
# Processing Record 2 of Set 14 | nizhniy baskunchak
# Processing Record 3 of Set 14 | vinzili
# Processing Record 4 of Set 14 | shelomi
# Processing Record 5 of Set 14 | beckley
# Processing Record 6 of Set 14 | kuzovatovo
# Processing Record 7 of Set 14 | bara
# Processing Record 8 of Set 14 | koyilandi
# City not found. Skipping...
# Processing Record 9 of Set 14 | uenohara
# Processing Record 10 of Set 14 | erzin
# Processing Record 11 of Set 14 | nara
# Processing Record 12 of Set 14 | lanzhou
# Processing Record 13 of Set 14 | margate
# Processing Record 14 of Set 14 | feijo
# Processing Record 15 of Set 14 | lucapa
# Processing Record 16 of Set 14 | yanji
# Processing Record 17 of Set 14 | pangody
# Processing Record 18 of Set 14 | daloa
# Processing Record 19 of Set 14 | at-bashi
# Processing Record 20 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 14 | yenagoa
# Processing Record 22 of Set 14 | mahon
# Processing Record 23 of Set 14 | formosa do rio preto
# Processing Record 24 of Set 14 | kayanza
# Processing Record 25 of Set 14 | virbalis
# Processing Record 26 of Set 14 | havelock
# Processing Record 27 of Set 14 | bagdarin
# Processing Record 28 of Set 14 | qadirpur ran
# Processing Record 29 of Set 14 | smithville
# Processing Record 30 of Set 14 | shushenskoye
# Processing Record 31 of Set 14 | birao
# Processing Record 32 of Set 14 | iberia
# Processing Record 33 of Set 14 | whitianga
# Processing Record 34 of Set 14 | ekhabi
# Processing Record 35 of Set 14 | kralendijk
# Processing Record 36 of Set 14 | gat
# Processing Record 37 of Set 14 | bontang
# Processing Record 38 of Set 14 | aiken
# Processing Record 39 of Set 14 | pacific grove
# Processing Record 40 of Set 14 | emmett
# Processing Record 41 of Set 14 | mackay
# Processing Record 42 of Set 14 | chiredzi
# Processing Record 43 of Set 14 | davenda
# Processing Record 44 of Set 14 | cassilandia
# Processing Record 45 of Set 14 | port pirie
# Processing Record 46 of Set 14 | petropavl
# Processing Record 47 of Set 14 | zabaykalsk
# Processing Record 48 of Set 14 | yialos
# City not found. Skipping...
# Processing Record 49 of Set 14 | bonavista
# Processing Record 50 of Set 14 | visnes
# Processing Record 1 of Set 15 | belawan
# Processing Record 2 of Set 15 | portree
# Processing Record 3 of Set 15 | urumqi
# Processing Record 4 of Set 15 | karamea
# City not found. Skipping...
# Processing Record 5 of Set 15 | porbandar
# Processing Record 6 of Set 15 | ust-nera
# Processing Record 7 of Set 15 | sikonge
# Processing Record 8 of Set 15 | cap-chat
# Processing Record 9 of Set 15 | otradnoye
# Processing Record 10 of Set 15 | miraflores
# Processing Record 11 of Set 15 | claveria
# Processing Record 12 of Set 15 | oussouye
# Processing Record 13 of Set 15 | moerai
# Processing Record 14 of Set 15 | clive
# Processing Record 15 of Set 15 | ramgarh
# Processing Record 16 of Set 15 | sitio novo do tocantins
# Processing Record 17 of Set 15 | blagoveshchenka
# Processing Record 18 of Set 15 | faya
# Processing Record 19 of Set 15 | ruidoso
# Processing Record 20 of Set 15 | palmer
# Processing Record 21 of Set 15 | hailey
# Processing Record 22 of Set 15 | kalmunai
# Processing Record 23 of Set 15 | churapcha
# Processing Record 24 of Set 15 | sisimiut
# Processing Record 25 of Set 15 | eyl
# Processing Record 26 of Set 15 | cayenne
# Processing Record 27 of Set 15 | bandar-e anzali
# Processing Record 28 of Set 15 | tabou
# Processing Record 29 of Set 15 | san quintin
# Processing Record 30 of Set 15 | minot
# Processing Record 31 of Set 15 | guangyuan
# Processing Record 32 of Set 15 | khani
# Processing Record 33 of Set 15 | bundaberg
# Processing Record 34 of Set 15 | nova olimpia
# Processing Record 35 of Set 15 | come
# Processing Record 36 of Set 15 | sayville
# Processing Record 37 of Set 15 | grafton
# Processing Record 38 of Set 15 | necochea
# Processing Record 39 of Set 15 | vrangel
# Processing Record 40 of Set 15 | mersing
# Processing Record 41 of Set 15 | boa vista
# Processing Record 42 of Set 15 | itoman
# Processing Record 43 of Set 15 | strelka
# Processing Record 44 of Set 15 | bilibino
# Processing Record 45 of Set 15 | lavras
# Processing Record 46 of Set 15 | olinda
# Processing Record 47 of Set 15 | tiarei
# Processing Record 48 of Set 15 | tongren
# Processing Record 49 of Set 15 | bairiki
# Processing Record 50 of Set 15 | tari
# Processing Record 1 of Set 16 | koumac
# Processing Record 2 of Set 16 | macheng
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# 696

# %%
#Save the new DataFrame as a CSV file
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0                 hobart      AU -42.8794  147.3294     57.06        81
# 1                 torbay      CA  47.6666  -52.7314     39.88        48
# 2                  vaini      TO -21.2000 -175.2000     75.36        94
# 3                  pevek      RU  69.7008  170.3133     -5.71        82
# 4                ushuaia      AR -54.8000  -68.3000     53.22        54
# 5             bredasdorp      ZA -34.5322   20.0403     72.72        83
# 6                rikitea      PF -23.1203 -134.9692     77.83        72
# 7                 barrow      US  71.2906 -156.7887    -13.54       100
# 8                  ronne      DK  55.1009   14.7066     37.31        60
# 9  gafanha da encarnacao      PT  40.6181   -8.7330     57.31        68
#
#    Cloudiness  Wind Speed Current Description
# 0          40        5.75    scattered clouds
# 1          75       23.02       broken clouds
# 2          40        4.61    scattered clouds
# 3           4        3.71           clear sky
# 4          40       25.32    scattered clouds
# 5         100        4.61     overcast clouds
# 6          10        4.03           clear sky
# 7         100        7.61     overcast clouds
# 8           2       13.80           clear sky
# 9          97       10.07     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
